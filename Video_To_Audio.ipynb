# %% [markdown]
# <a href="https://colab.research.google.com/github/Arshnoor7/Mini-Project-Video-to-Audio/blob/main/Video_To_Audio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Install necessary packages**

# %%
# !pip install moviepy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# **Program for converting video to audio**

# %%
from moviepy.editor import VideoFileClip
import os
def convert_video_to_audio_moviepy(video_file, output_ext="mp3"):
    """Converts video to audio using MoviePy library
    that uses `ffmpeg` under the hood"""
    filename, ext = os.path.splitext(video_file)
    clip = VideoFileClip(video_file)
    clip.audio.write_audiofile(f"{filename}.{output_ext}")

# %%
convert_video_to_audio_moviepy('/content/test.mp4')
# Out:
# MoviePy - Writing audio in /content/test.mp3
# MoviePy - Done.
